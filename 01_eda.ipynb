# %%
import pandas as pd

# Match results
results = pd.read_csv('../data/raw/results.csv')

# FIFA rankings
fifa_rankings = pd.read_csv('../data/raw/fifa_rankings.csv')

# Transfermarkt files
players = pd.read_csv('../data/raw/transfermarkt/players.csv')
player_valuations = pd.read_csv('../data/raw/transfermarkt/player_valuations.csv')
national_teams = pd.read_csv('../data/raw/transfermarkt/national_teams.csv')
games = pd.read_csv('../data/raw/transfermarkt/games.csv')
game_lineups = pd.read_csv('../data/raw/transfermarkt/game_lineups.csv', low_memory=False)

# %%
game_lineups['number'].unique()
# Out:
# <StringArray>
# [  '5',   '4',  '11',  '17',  '23',  '29',   '1',  '20',  '12',  '16',
#  ...
#  '195', '232', '218', '136', '241', '142', '256', '170', '139', '206']
# Length: 169, dtype: str

# %%
results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
results.shape
# Out:
# (49411, 9)

# %%
results.info
# Out:
# <bound method DataFrame.info of              date home_team   away_team  home_score  away_score  \
# 0      1872-11-30  Scotland     England         0.0         0.0
# 1      1873-03-08   England    Scotland         4.0         2.0
# 2      1874-03-07  Scotland     England         2.0         1.0
# 3      1875-03-06   England    Scotland         2.0         2.0
# 4      1876-03-04  Scotland     England         3.0         0.0
# ...           ...       ...         ...         ...         ...
# 49406  2026-06-27    Jordan   Argentina         NaN         NaN
# 49407  2026-06-27  Colombia    Portugal         NaN         NaN
# 49408  2026-06-27  DR Congo  Uzbekistan         NaN         NaN
# 49409  2026-06-27    Panama     England         NaN         NaN
# 49410  2026-06-27   Croatia       Ghana         NaN         NaN
#
#            tournament             city        country  neutral
# 0            Friendly          Glasgow       Scotland    False
# ...

# %%
results.isnull().sum()
# Out:
# date           0
# home_team      0
# away_team      0
# home_score    72
# away_score    72
# tournament     0
# city           0
# country        0
# neutral        0
# dtype: int64

# %%
results.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49411 entries, 0 to 49410
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        49411 non-null  str
#  1   home_team   49411 non-null  str
#  2   away_team   49411 non-null  str
#  3   home_score  49339 non-null  float64
#  4   away_score  49339 non-null  float64
#  5   tournament  49411 non-null  str
#  6   city        49411 non-null  str
#  7   country     49411 non-null  str
#  8   neutral     49411 non-null  bool
# dtypes: bool(1), float64(2), str(6)
# memory usage: 3.1 MB

# %%
fifa_rankings.head()
# Out:
#    Unnamed: 0   rank       country_full country_abrv  total_points  \
# 0           0  140.0  Brunei Darussalam          BRU           2.0
# 1           1   33.0           Portugal          POR          38.0
# 2           2   32.0             Zambia          ZAM          38.0
# 3           3   31.0             Greece          GRE          38.0
# 4           4   30.0            Algeria          ALG          39.0
#
#    previous_points  rank_change confederation   rank_date
# 0              0.0          140           AFC  1992-12-31
# 1              0.0           33          UEFA  1992-12-31
# 2              0.0           32           CAF  1992-12-31
# 3              0.0           31          UEFA  1992-12-31
# 4              0.0           30           CAF  1992-12-31

# %%
fifa_rankings.shape
# Out:
# (70194, 9)

# %%
fifa_rankings.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 70194 entries, 0 to 70193
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       70194 non-null  int64
#  1   rank             70185 non-null  float64
#  2   country_full     70194 non-null  str
#  3   country_abrv     70194 non-null  str
#  4   total_points     70194 non-null  float64
#  5   previous_points  70194 non-null  float64
#  6   rank_change      70194 non-null  int64
#  7   confederation    70194 non-null  str
#  8   rank_date        70194 non-null  str
# dtypes: float64(3), int64(2), str(4)
# memory usage: 4.8 MB

# %%
fifa_rankings.isnull().sum()
# Out:
# Unnamed: 0         0
# rank               9
# country_full       0
# country_abrv       0
# total_points       0
# previous_points    0
# rank_change        0
# confederation      0
# rank_date          0
# dtype: int64

# %%
fifa_rankings[fifa_rankings['rank'].isnull()]
# Out:
#        Unnamed: 0  rank    country_full country_abrv  total_points  \
# 66339       66339   NaN         Eritrea          ERI        855.56
# 66340       66340   NaN           Tonga          TGA        861.81
# 66341       66341   NaN           Samoa          SAM        894.26
# 66342       66342   NaN  American Samoa          ASA        900.27
# 66493       66493   NaN         Eritrea          ERI        855.56
# 66734       66734   NaN         Eritrea          ERI        855.56
# 66919       66919   NaN         Eritrea          ERI        855.56
# 67134       67134   NaN         Eritrea          ERI        855.56
# 67393       67393   NaN         Eritrea          ERI        855.56
#
#        previous_points  rank_change confederation   rank_date
# 66339              0.0            0           CAF  2023-10-26
# 66340              0.0            0           OFC  2023-10-26
# 66341              0.0            0           OFC  2023-10-26
# ...

# %%
players.head()
players.shape
players.info()
players.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47701 entries, 0 to 47700
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             47701 non-null  int64
#  1   first_name                            44610 non-null  str
#  2   last_name                             47701 non-null  str
#  3   name                                  47701 non-null  str
#  4   last_season                           47701 non-null  int64
#  5   current_club_id                       47701 non-null  int64
#  6   player_code                           47701 non-null  str
#  7   country_of_birth                      42535 non-null  str
#  8   city_of_birth                         42811 non-null  str
#  9   country_of_citizenship                47428 non-null  str
#  10  date_of_birth                         47652 non-null  str
# ...

# %%
players.head()
# Out:
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...            agent_name  \
# ...

# %%
players.shape
# Out:
# (47701, 26)

# %%
players.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47701 entries, 0 to 47700
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             47701 non-null  int64
#  1   first_name                            44610 non-null  str
#  2   last_name                             47701 non-null  str
#  3   name                                  47701 non-null  str
#  4   last_season                           47701 non-null  int64
#  5   current_club_id                       47701 non-null  int64
#  6   player_code                           47701 non-null  str
#  7   country_of_birth                      42535 non-null  str
#  8   city_of_birth                         42811 non-null  str
#  9   country_of_citizenship                47428 non-null  str
#  10  date_of_birth                         47652 non-null  str
# ...

# %%
players.isnull().sum
# Out:
# <bound method DataFrame.sum of        player_id  first_name  last_name   name  last_season  current_club_id  \
# 0          False       False      False  False        False            False
# 1          False       False      False  False        False            False
# 2          False       False      False  False        False            False
# 3          False        True      False  False        False            False
# 4          False       False      False  False        False            False
# ...          ...         ...        ...    ...          ...              ...
# 47696      False       False      False  False        False            False
# 47697      False       False      False  False        False            False
# 47698      False       False      False  False        False            False
# 47699      False       False      False  False        False            False
# 47700      False       False      False  False        False            False
#
# ...

# %%
player_valuations.head()
# Out:
#    player_id        date  market_value_in_eur current_club_name  \
# 0     405973  2000-01-20               150000           Unknown
# 1     342216  2001-07-20               100000           Unknown
# 2       3132  2003-12-09               400000       Dynamo Kyiv
# 3       6893  2003-12-15               900000       Galatasaray
# 4         10  2004-10-04              7000000  SV Werder Bremen
#
#    current_club_id player_club_domestic_competition_id
# 0             3057                                 BE1
# 1             1241                                 SC1
# 2              126                                 TR1
# 3              984                                 GB1
# 4              398                                 IT1

# %%
player_valuations.shape
# Out:
# (507815, 6)

# %%
player_valuations.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 507815 entries, 0 to 507814
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   player_id                            507815 non-null  int64
#  1   date                                 507815 non-null  str
#  2   market_value_in_eur                  507815 non-null  int64
#  3   current_club_name                    507815 non-null  str
#  4   current_club_id                      507815 non-null  int64
#  5   player_club_domestic_competition_id  485216 non-null  str
# dtypes: int64(3), str(3)
# memory usage: 23.2 MB

# %%
player_valuations.isnull().sum()
# Out:
# player_id                                  0
# date                                       0
# market_value_in_eur                        0
# current_club_name                          0
# current_club_id                            0
# player_club_domestic_competition_id    22599
# dtype: int64

# %%
national_teams.head()
# Out:
#    national_team_id        name   team_code  country_id country_name  \
# 0             10521  San Marino  san-marino         144   San Marino
# 1             10533     Andorra     andorra           5      Andorra
# 2             11953  Montenegro  montenegro         216   Montenegro
# 3             13342   Guatemala   guatemala          58    Guatemala
# 4             13497      Uganda      uganda         176       Uganda
#
#   country_code confederation  \
# 0         SMR1          UEFA
# 1         AND2          UEFA
# 2         MNE1          UEFA
# 3         GU1A      CONCACAF
# 4         UGL1           CAF
#
#                                       team_image_url  squad_size  average_age  \
# 0  https://tmssl.akamaized.net//images/flagge/hea...          24         24.9
# 1  https://tmssl.akamaized.net//images/flagge/hea...          26         29.2
# 2  https://tmssl.akamaized.net//images/flagge/hea...          26         28.3
# ...

# %%
national_teams.shape
# Out:
# (118, 17)

# %%
national_teams.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   national_team_id       118 non-null    int64
#  1   name                   118 non-null    str
#  2   team_code              118 non-null    str
#  3   country_id             118 non-null    int64
#  4   country_name           118 non-null    str
#  5   country_code           118 non-null    str
#  6   confederation          117 non-null    str
#  7   team_image_url         118 non-null    str
#  8   squad_size             118 non-null    int64
#  9   average_age            118 non-null    float64
#  10  foreigners_number      118 non-null    int64
#  11  foreigners_percentage  113 non-null    float64
#  12  total_market_value     115 non-null    float64
#  13  coach_name             0 non-null      float64
#  14  fifa_ranking           118 non-null    int64
# ...

# %%
national_teams.isnull().sum()
# Out:
# national_team_id           0
# name                       0
# team_code                  0
# country_id                 0
# country_name               0
# country_code               0
# confederation              1
# team_image_url             0
# squad_size                 0
# average_age                0
# foreigners_number          0
# foreigners_percentage      5
# total_market_value         3
# coach_name               118
# fifa_ranking               0
# last_season                0
# url                        0
# dtype: int64

# %%
results_teams = set(results['home_team'].unique()) | set(results['away_team'].unique())
rankings_teams = set(fifa_rankings['country_full'].unique())

# Teams in results but not in rankings
print(results_teams - rankings_teams)

# Teams in rankings but not in results
print(rankings_teams - results_teams)
# Out:
# {'Frøya', 'Padania', 'Alderney', 'Åland Islands', 'West Papua', 'Mapuche', 'Saint Barthélemy', 'Gozo', 'Yorkshire', 'Felvidék', 'Greenland', 'Tibet', 'Catalonia', 'Guernsey', 'Western Isles', 'Hitra', 'Maule Sur', 'Arameans Suryoye', 'Réunion', 'Monaco', 'Hong Kong', 'Délvidék', 'South Korea', 'Găgăuzia', 'United States Virgin Islands', 'Saugeais', 'Cilento', 'Isle of Wight', 'Silesia', 'Parishes of Jersey', 'Brittany', 'Kurdistan', 'Marshall Islands', 'Martinique', 'Guadeloupe', 'Hmong', 'Mayotte', 'Panjab', 'Two Sicilies', 'Quebec', 'Yoruba Nation', 'Vietnam Republic', 'Aymara', 'Ellan Vannin', 'North Korea', 'South Yemen', 'Niue', 'Tamil Eelam', 'Barawa', 'Ambazonia', 'North Vietnam', 'Crimea', 'Western Armenia', 'Kárpátalja', 'Darfur', 'Shetland', 'Manchukuo', 'Kernow', 'Somaliland', 'Andalusia', 'Sealand', 'Rhodes', 'Occitania', 'Sark', 'Jersey', 'United Koreans in Japan', 'Artsakh', 'Székely Land', 'Micronesia', 'Saarland', 'Ivory Coast', 'Turkey', 'Zanzibar', 'Western Australi
# ...

# %%
world_cup_teams = set(
    results[results['tournament'] == 'FIFA World Cup']['home_team'].unique()
) | set(
    results[results['tournament'] == 'FIFA World Cup']['away_team'].unique()
)

print(world_cup_teams)
# Out:
# {'Wales', 'Israel', 'Hungary', 'United Arab Emirates', 'Iraq', 'Colombia', 'Cuba', 'Haiti', 'Portugal', 'Netherlands', 'Egypt', 'South Korea', 'Uzbekistan', 'Denmark', 'Peru', 'Brazil', 'Republic of Ireland', 'Belgium', 'Honduras', 'Czechoslovakia', 'Spain', 'Serbia', 'Saudi Arabia', 'Jordan', 'Switzerland', 'Yugoslavia', 'Slovakia', 'North Korea', 'Panama', 'Indonesia', 'Togo', 'England', 'Nigeria', 'Tunisia', 'Austria', 'Canada', 'Iceland', 'Bolivia', 'Italy', 'Germany', 'Ivory Coast', 'Turkey', 'Jamaica', 'Bulgaria', 'China PR', 'Chile', 'New Zealand', 'Czech Republic', 'United States', 'Ukraine', 'Ecuador', 'Japan', 'Curaçao', 'Qatar', 'Argentina', 'Romania', 'France', 'Ghana', 'El Salvador', 'DR Congo', 'Slovenia', 'Bosnia and Herzegovina', 'Poland', 'Paraguay', 'Croatia', 'Norway', 'German DR', 'South Africa', 'Kuwait', 'Algeria', 'Cameroon', 'Trinidad and Tobago', 'Sweden', 'Senegal', 'Australia', 'Iran', 'Angola', 'Russia', 'Cape Verde', 'Greece', 'Uruguay', 'Scotland', 'Mexi
# ...

# %%
edge_cases = ['Republic of Ireland', 'China PR', 'Serbia', 'Bosnia and Herzegovina', 'Curaçao']

for team in edge_cases:
    in_rankings = team in set(fifa_rankings['country_full'].unique())
    print(f"{team}: {'✓ found' if in_rankings else '✗ not found'}")
# Out:
# Republic of Ireland: ✓ found
# China PR: ✓ found
# Serbia: ✓ found
# Bosnia and Herzegovina: ✓ found
# Curaçao: ✓ found

# %%
results
# Out:
#              date home_team   away_team  home_score  away_score  \
# 0      1872-11-30  Scotland     England         0.0         0.0
# 1      1873-03-08   England    Scotland         4.0         2.0
# 2      1874-03-07  Scotland     England         2.0         1.0
# 3      1875-03-06   England    Scotland         2.0         2.0
# 4      1876-03-04  Scotland     England         3.0         0.0
# ...           ...       ...         ...         ...         ...
# 49406  2026-06-27    Jordan   Argentina         NaN         NaN
# 49407  2026-06-27  Colombia    Portugal         NaN         NaN
# 49408  2026-06-27  DR Congo  Uzbekistan         NaN         NaN
# 49409  2026-06-27    Panama     England         NaN         NaN
# 49410  2026-06-27   Croatia       Ghana         NaN         NaN
#
#            tournament             city        country  neutral
# 0            Friendly          Glasgow       Scotland    False
# 1            Friendly           London        England    False
# ...

# %%
results.dtypes
# Out:
# date              str
# home_team         str
# away_team         str
# home_score    float64
# away_score    float64
# tournament        str
# city              str
# country           str
# neutral          bool
# dtype: object

# %%
results['date'] = pd.to_datetime(results['date'])

# %%
results.dtypes
# Out:
# date          datetime64[us]
# home_team                str
# away_team                str
# home_score           float64
# away_score           float64
# tournament               str
# city                     str
# country                  str
# neutral                 bool
# dtype: object

# %%
results.replace({
    'South Korea': 'Korea Republic',
    'North Korea': 'Korea DPR',
    'Ivory Coast': "Côte d'Ivoire",
    'Turkey': 'Türkiye',
    'Iran': 'IR Iran',
    'United States': 'USA',
    'DR Congo': 'Congo DR',
    'Czech Republic': 'Czechia',
    'Cape Verde': 'Cabo Verde'
}
)
# Out:
#             date home_team   away_team  home_score  away_score  \
# 0     1872-11-30  Scotland     England         0.0         0.0
# 1     1873-03-08   England    Scotland         4.0         2.0
# 2     1874-03-07  Scotland     England         2.0         1.0
# 3     1875-03-06   England    Scotland         2.0         2.0
# 4     1876-03-04  Scotland     England         3.0         0.0
# ...          ...       ...         ...         ...         ...
# 49406 2026-06-27    Jordan   Argentina         NaN         NaN
# 49407 2026-06-27  Colombia    Portugal         NaN         NaN
# 49408 2026-06-27  Congo DR  Uzbekistan         NaN         NaN
# 49409 2026-06-27    Panama     England         NaN         NaN
# 49410 2026-06-27   Croatia       Ghana         NaN         NaN
#
#            tournament             city   country  neutral
# 0            Friendly          Glasgow  Scotland    False
# 1            Friendly           London   England    False
# ...

# %%
results
# Out:
#             date home_team   away_team  home_score  away_score  \
# 0     1872-11-30  Scotland     England         0.0         0.0
# 1     1873-03-08   England    Scotland         4.0         2.0
# 2     1874-03-07  Scotland     England         2.0         1.0
# 3     1875-03-06   England    Scotland         2.0         2.0
# 4     1876-03-04  Scotland     England         3.0         0.0
# ...          ...       ...         ...         ...         ...
# 49406 2026-06-27    Jordan   Argentina         NaN         NaN
# 49407 2026-06-27  Colombia    Portugal         NaN         NaN
# 49408 2026-06-27  DR Congo  Uzbekistan         NaN         NaN
# 49409 2026-06-27    Panama     England         NaN         NaN
# 49410 2026-06-27   Croatia       Ghana         NaN         NaN
#
#            tournament             city        country  neutral
# 0            Friendly          Glasgow       Scotland    False
# 1            Friendly           London        England    False
# ...

# %%
results = results.replace({
    'South Korea': 'Korea Republic',
    'North Korea': 'Korea DPR',
    'Ivory Coast': "Côte d'Ivoire",
    'Turkey': 'Türkiye',
    'Iran': 'IR Iran',
    'United States': 'USA',
    'DR Congo': 'Congo DR',
    'Czech Republic': 'Czechia',
    'Cape Verde': 'Cabo Verde'
}
)

# %%
# Check none of the old names remain
old_names = ['South Korea', 'Ivory Coast', 'Turkey', 'Iran', 'United States', 'DR Congo', 'Czech Republic', 'Cape Verde']

for name in old_names:
    found = (results['home_team'] == name).any() or (results['away_team'] == name).any()
    print(f"{name}: {'✗ still exists' if found else '✓ replaced'}")
# Out:
# South Korea: ✓ replaced
# Ivory Coast: ✓ replaced
# Turkey: ✓ replaced
# Iran: ✓ replaced
# United States: ✓ replaced
# DR Congo: ✓ replaced
# Czech Republic: ✓ replaced
# Cape Verde: ✓ replaced

# %%
historical_results = results.notna()

# %%
historical_results
# Out:
#        date  home_team  away_team  home_score  away_score  tournament  city  \
# 0      True       True       True        True        True        True  True
# 1      True       True       True        True        True        True  True
# 2      True       True       True        True        True        True  True
# 3      True       True       True        True        True        True  True
# 4      True       True       True        True        True        True  True
# ...     ...        ...        ...         ...         ...         ...   ...
# 49406  True       True       True       False       False        True  True
# 49407  True       True       True       False       False        True  True
# 49408  True       True       True       False       False        True  True
# 49409  True       True       True       False       False        True  True
# 49410  True       True       True       False       False        True  True
#
#        country  neutral
# 0         True     True
# ...

# %%
historical_results = results[results['home_score'].notna()]

# %%
historical_results
# Out:
#             date                 home_team     away_team  home_score  \
# 0     1872-11-30                  Scotland       England         0.0
# 1     1873-03-08                   England      Scotland         4.0
# 2     1874-03-07                  Scotland       England         2.0
# 3     1875-03-06                   England      Scotland         2.0
# 4     1876-03-04                  Scotland       England         3.0
# ...          ...                       ...           ...         ...
# 49334 2026-06-05                    Russia  Burkina Faso         3.0
# 49335 2026-06-05                     Benin         Niger         1.0
# 49336 2026-06-05  Central African Republic          Togo         1.0
# 49337 2026-06-05               Puerto Rico  Saudi Arabia         0.0
# 49338 2026-06-05                   Vanuatu          Fiji         2.0
#
#        away_score tournament        city   country  neutral
# 0             0.0   Friendly     Glasgow  Scotland    False
# ...

# %%
future_fixtures = results[results['home_score'].isnull()]

# %%
future_fixtures
# Out:
#             date       home_team               away_team  home_score  \
# 49339 2026-06-11          Mexico            South Africa         NaN
# 49340 2026-06-11  Korea Republic                 Czechia         NaN
# 49341 2026-06-12          Canada  Bosnia and Herzegovina         NaN
# 49342 2026-06-12             USA                Paraguay         NaN
# 49343 2026-06-13           Qatar             Switzerland         NaN
# ...          ...             ...                     ...         ...
# 49406 2026-06-27          Jordan               Argentina         NaN
# 49407 2026-06-27        Colombia                Portugal         NaN
# 49408 2026-06-27        Congo DR              Uzbekistan         NaN
# 49409 2026-06-27          Panama                 England         NaN
# 49410 2026-06-27         Croatia                   Ghana         NaN
#
#        away_score      tournament             city country  neutral
# 49339         NaN  FIFA World Cup      Mexico City  Mexico    False
# ...

# %%
print(historical_results.shape)
print(future_fixtures.shape)
print(historical_results.shape[0] + future_fixtures.shape[0])
# Out:
# (49339, 9)
# (72, 9)
# 49411

# %%
historical_results['home_score'] = historical_results['home_score'].astype(int)

# %%
historical_results['away_score'] = historical_results['away_score'].astype(int)

# %%
historical_results[['home_score', 'away_score']].dtypes
# Out:
# home_score    int64
# away_score    int64
# dtype: object

# %%
import numpy as np

conditions = [
    historical_results['home_score'] > historical_results['away_score'],
    historical_results['home_score'] < historical_results['away_score'],
    historical_results['home_score'] == historical_results['away_score']
]

choices = [
    'Home Win',
    'Away Win',
    'Draw'
]

historical_results.loc[:, 'outcome'] = np.select(conditions, choices, default='Unknown')

# %%
historical_results['outcome'].value_counts()
# Out:
# outcome
# Home Win    24177
# Away Win    13943
# Draw        11219
# Name: count, dtype: int64

# %%
historical_results['tournament'].value_counts()
# Out:
# tournament
# Friendly                                18333
# FIFA World Cup qualification             8771
# UEFA Euro qualification                  2824
# African Cup of Nations qualification     2327
# FIFA World Cup                            964
#                                         ...
# Copa Confraternidad                         1
# Benedikt Fontana Cup                        1
# ConIFA Challenger Cup                       1
# CONIFA World Cup qualification              1
# South Asian Super Cup                       1
# Name: count, Length: 199, dtype: int64

# %%
print(historical_results['tournament'].unique())
# Out:
# <StringArray>
# [                                         'Friendly',
#                          'British Home Championship',
#                               'Évence Coppée Trophy',
#                                       'Muratti Vase',
#                                        'Copa Lipton',
#                                        'Copa Newton',
#                        'Copa Premio Honor Argentino',
#                                      'Olympic Games',
#                         'Copa Premio Honor Uruguayo',
#                     'Far Eastern Championship Games',
#  ...
#                    'EAFF Championship qualification',
#                                      'Mapinduzi Cup',
#                                    'Canadian Shield',
#                            'Outrigger Challenge Cup',
#                              'South Asian Super Cup',
#                                    'CONCACAF Series',
#                           'Al Ain International Cup',
# ...

# %%
tournament_weights = {
    # Tier 4 - World Cup
    'FIFA World Cup': 4,
    
    # Tier 3 - Major tournaments
    'UEFA Euro': 3,
    'Copa América': 3,   
    'African Cup of Nations': 3,
    'AFC Asian Cup': 3,
    'Gold Cup': 3,

    
    # Tier 2 - Qualification
    'FIFA World Cup qualification': 2,
    'UEFA Euro qualification': 2,
    'African Cup of Nations qualification': 2,
    'AFC Asian Cup qualification': 2,
    'Gold Cup qualification': 2,
    
    # Tier 1 - Friendly
    'Friendly': 1,
    'Olympic Games': 1
}

historical_results.loc[:, 'tournament_weight'] = historical_results['tournament'].map(tournament_weights).fillna(1).astype(int)

# %%
historical_results['tournament_weight'].value_counts()
# Out:
# tournament_weight
# 1    30593
# 2    14839
# 3     2943
# 4      964
# Name: count, dtype: int64

# %%
historical_results[historical_results['tournament'] == 'FIFA World Cup']['tournament_weight'].unique()
# Out:
# array([4])

# %%
historical_results.to_csv('../data/processed/historical_results.csv', index=False)
future_fixtures.to_csv('../data/processed/future_fixtures.csv', index=False)

# %%
fifa_rankings['rank_date'] = pd.to_datetime(fifa_rankings['rank_date'])

# %%
fifa_rankings = fifa_rankings.drop('Unnamed: 0', axis=1)

# %%
fifa_rankings = fifa_rankings[fifa_rankings['rank'].notna()]

# %%
fifa_rankings.shape
# Out:
# (70185, 8)

# %%
fifa_rankings.to_csv('../data/processed/fifa_rankings_clean.csv', index=False)

# %%
players = players[['player_id', 'name', 'country_of_citizenship', 'position', 'international_caps', 'market_value_in_eur']]

# %%
players = players[players['country_of_citizenship'].notna()]

# %%
players.shape
# Out:
# (47428, 6)

# %%
player_valuations = player_valuations.drop('player_club_domestic_competition_id', axis = 1)

# %%
player_valuations['date'] = pd.to_datetime(player_valuations['date'])

# %%
player_valuations.shape
# Out:
# (507815, 5)

# %%
player_valuations.to_csv('../data/processed/player_valuations_clean.csv', index=False)

# %%
national_teams = national_teams[['national_team_id', 'name', 'country_name', 'confederation']]

# %%
national_teams.shape
# Out:
# (118, 4)

# %%
national_teams.to_csv('../data/processed/national_teams_clean.csv', index=False)

# %%
players.to_csv('../data/processed/players_clean.csv', index=False)
